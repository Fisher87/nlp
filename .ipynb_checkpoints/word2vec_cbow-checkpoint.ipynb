# %% [markdown]
# ## word2vec
# > 训练一个Word2Vec CBOW的模型
#
# 参考文档:
#
# + [探秘Word2Vec(四)-CBOW模型](https://www.jianshu.com/p/d534570272a6)

# %%
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# D:\anaconda\anaconda3.6\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### 1.加载数据

# %%
url = 'http://mattmahoney.net/dc/'
def downloadData(filename, excepted_bytes):
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == excepted_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
              'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

def read_data(filename):
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

filename = downloadData('text8.zip', 31344016)
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Found and verified text8.zip
# Data size 17005207

# %% [markdown]
# ### 2. 创建数据集

# %%
# vocabulary size
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size-1))
    
    # word - index hashing
    dictionary = dict()
    for word,_ in count:
        dictionary[word] = len(dictionary)
        
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
  
    count[0][1] = unk_count
    # index - word hashing  
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
#del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size//num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)

    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
  
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i] = buffer[skip_window]
            labels[i*num_skips+j] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
        batch1=labels.reshape(batch_size//num_skips,num_skips)
        labels1=batch.reshape(batch_size//num_skips,1)
    return batch1,labels1

print('data:', [reverse_dictionary[di] for di in data[:8]])
print(data[:8])
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch_size=8
    batch, labels = generate_batch(batch_size, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(batch_size)])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(batch_size//num_skips)])
    print(batch,labels)
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# [5234, 3081, 12, 6, 195, 2, 3134, 46]
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#     labels: ['originated', 'as', 'a', 'term']
# [[  12 5234]
#  [   6 3081]
#  [  12  195]
#  [   2    6]] [[3081]
#  [  12]
#  [   6]
#  [ 195]]
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['term', 'a', 'anarchism', 'originated', 'originated', 'as', 'of', 'term']
#     labels: ['as', 'a']
# [[ 195    6 5234 3081]
#  [3081   12    2  195]] [[12]
#  [ 6]]

# %%
batch_size = 256
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size//num_skips,num_skips])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size//num_skips, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.均匀分布
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],mean=0.0,
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = sum(tf.nn.embedding_lookup(embeddings, train_dataset[:,i]) for i in range(num_skips))
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, train_labels,
                                 embed, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    # 正则化的embeddings
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 40001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')

    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
    
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From D:\anaconda\anaconda3.6\lib\site-packages\tensorflow\python\util\tf_should_use.py:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.861026
# Nearest to world: wahid, stings, starvation, anic, curses, amf, genres, plebeian,
# Nearest to zero: numismatic, cornelis, mushrooms, wished, triangle, salina, gentoo, druidry,
# Nearest to also: indices, phosphate, collar, deference, millet, reset, theists, fishery,
# Nearest to see: utmost, linkage, his, wiesbaden, forgetful, apeiron, pimp, helical,
# Nearest to b: mart, cns, aitken, rollins, iverson, ppt, slowest, nonaggression,
# Nearest to over: idempotent, nadezhda, musket, reminds, teri, dan, tristan, remade,
# Nearest to would: wissenschaft, stadia, occultists, connect, theoretically, dares, innumerable, pics,
# Nearest to but: tonne, transcription, grabbed, inlet, exhumed, armouries, custom, crowning,
# Nearest to history: aegean, taken, chaotic, disconcerting, gomez, lesson, wto, tyrell,
# Nearest to as: whither, vedanta, reproduce, instances, indomitable, liberally, unicycle, probing,
# Nearest to he: wrest, livius, purim, glucocorticoids, sentiments, wilson, goats, marquess,
# Nearest to many: nyquist, kvac, foodstuffs, est, dreaded, sheldon, menorah, microevolution,
# Nearest to with: grub, anno, odorless, lear, wong, basileus, liners, donelson,
# Nearest to are: sarcoma, lepidus, magellanic, nanking, penang, swearing, boilers, naughton,
# Nearest to most: clitic, agesilaus, imprinted, thrower, lockout, gokturk, uncompetitive, integrin,
# Nearest to or: ionospheric, mechanics, blackbeard, bova, sceptical, francois, therefrom, vespers,
# Average loss at step 2000: 4.091266
# Average loss at step 4000: 3.568622
# Average loss at step 6000: 3.389632
# Average loss at step 8000: 3.245737
# Average loss at step 10000: 3.177586
# Nearest to world: nominated, theorems, decomposed, servicing, disarmed, country, late, brie,
# Nearest to zero: eight, five, four, nine, seven, six, three, two,
# Nearest to also: never, often, sometimes, not, which, halal, still, livius,
# Nearest to see: apeiron, sihanouk, hypostasis, hate, ti, hariri, anthony, cloistered,
# Nearest to b: d, microelectronics, polanyi, dunkirk, mart, gibbs, jonson, divides,
# Nearest to over: livres, scholastic, remade, yao, ys, about, argyle, berenson,
# Nearest to would: can, will, could, may, should, must, might, to,
# Nearest to but: however, and, which, facilitated, trinidad, rudder, though, while,
# Nearest to history: quantum, growing, metaphysical, afrikaans, texas, cements, chaotic, shells,
# Nearest to as: for, placentia, accusative, ling, reproduce, rubies, hgp, tahitian,
# Nearest to he: it, she, they, who, there, conceptualized, burglar, butlerian,
# Nearest to many: some, several, all, these, buckingham, popularity, amounts, immunotherapy,
# Nearest to with: between, horst, amelia, in, dubnium, khz, reckoned, enlarging,
# Nearest to are: were, is, have, reachable, hafnium, hus, was, penang,
# Nearest to most: more, mispronounced, thrower, electroshock, spectrometer, some, many, spiracles,
# Nearest to or: and, than, mosander, tait, stirrup, squadrons, siouxsie, unharmed,
# Average loss at step 12000: 3.203495
# Average loss at step 14000: 3.156566
# Average loss at step 16000: 3.174997
# Average loss at step 18000: 3.122308
# Average loss at step 20000: 2.991398
# Nearest to world: brie, ottoman, country, theorems, servicing, refugees, decomposed, disarmed,
# Nearest to zero: seven, six, eight, nine, five, four, three, rodolfo,
# Nearest to also: often, sometimes, still, which, never, typically, now, usually,
# Nearest to see: apeiron, include, shankar, ti, vivo, aged, owning, hypostasis,
# Nearest to b: d, polanyi, c, hollow, corbett, heckman, nasl, peaking,
# Nearest to over: livres, integrable, about, scholastic, charts, agm, thugs, remade,
# Nearest to would: will, could, can, should, may, might, must, did,
# Nearest to but: however, while, and, although, senile, sclerosis, it, yeager,
# Nearest to history: quantum, afrikaans, chaotic, amongst, socialite, refine, texas, dribbling,
# Nearest to as: when, slugger, reproduce, knowingly, ling, droll, turin, ipswich,
# Nearest to he: she, it, they, who, there, conceptualized, never, we,
# Nearest to many: some, several, these, various, other, most, all, whitehouse,
# Nearest to with: between, amelia, reckoned, in, nbs, colonisation, burke, anno,
# Nearest to are: were, have, is, be, dame, include, penang, reachable,
# Nearest to most: more, many, thrower, clitic, some, substance, electroshock, spiracles,
# Nearest to or: and, than, andersonville, nazism, flirting, oppidum, batavian, neighbor,
# Average loss at step 22000: 3.075419
# Average loss at step 24000: 3.040240
# Average loss at step 26000: 3.009076
# Average loss at step 28000: 3.024542
# Average loss at step 30000: 3.009515
# Nearest to world: prussian, theorems, leadership, brie, ottoman, century, maximise, exercise,
# Nearest to zero: seven, five, four, six, eight, nine, three, two,
# Nearest to also: now, often, still, never, sometimes, typically, which, actually,
# Nearest to see: but, include, according, apeiron, ti, cracker, called, proxies,
# Nearest to b: d, consul, ber, bentley, trident, mortgages, gracious, nasl,
# Nearest to over: into, about, pursues, scholastic, honours, through, outbursts, within,
# Nearest to would: will, could, can, may, should, might, must, cannot,
# Nearest to but: however, see, although, and, which, grover, while, are,
# Nearest to history: quantum, afrikaans, list, refine, luddite, memorabilia, krav, topics,
# Nearest to as: slugger, stow, reproduce, reorganization, turin, dma, unveiling, knowingly,
# Nearest to he: she, it, they, who, there, never, conceptualized, finally,
# Nearest to many: several, some, various, these, most, such, both, all,
# Nearest to with: between, medusa, yearly, amelia, sharps, reckoned, anno, squaring,
# Nearest to are: were, have, is, include, dame, but, balzac, konerko,
# Nearest to most: more, some, many, spectrometer, spiracles, transitioning, less, thrower,
# Nearest to or: and, than, stifling, andersonville, hoppers, but, mandibles, jacoby,
# Average loss at step 32000: 2.831855
# Average loss at step 34000: 2.958396
# Average loss at step 36000: 2.944199
# Average loss at step 38000: 2.943543
# Average loss at step 40000: 2.950016
# Nearest to world: brie, aryans, decomposed, theorems, superscript, century, prussian, leadership,
# Nearest to zero: seven, five, eight, six, three, nine, four, minutes,
# Nearest to also: often, still, now, which, never, sometimes, actually, ict,
# Nearest to see: include, cracker, includes, apeiron, irina, ti, according, cpi,
# Nearest to b: d, marginalized, starbuck, mathbb, rorty, mourns, consul, plea,
# Nearest to over: about, within, through, agm, into, scholastic, pulmonary, pursues,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to but: however, although, and, while, than, cassette, or, particularly,
# Nearest to history: anguish, quantum, list, underworld, afrikaans, development, airports, iodide,
# Nearest to as: reproduce, stow, condone, dma, reorganization, ketone, when, tunny,
# Nearest to he: she, it, they, there, who, finally, spenser, cartridges,
# Nearest to many: some, several, various, both, most, these, phane, all,
# Nearest to with: between, anno, amelia, by, reckoned, horst, into, classicist,
# Nearest to are: were, have, include, reachable, is, be, ultrasound, although,
# Nearest to most: more, less, many, some, very, spiracles, truncation, thrower,
# Nearest to or: and, whitespace, irvine, but, than, correspondance, spoilage, stirrup,

# %%
num_points = 400
# 降维度PCA
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
